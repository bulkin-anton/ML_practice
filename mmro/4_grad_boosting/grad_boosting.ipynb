# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 4. Разложение ошибки на смещение и разброс. Градиентный бустинг ~~своими руками~~
#
# ### Общая информация
#
# Дата выдачи: 2.12.2024
#
# Мягкий дедлайн: 23:59MSK 17.12.2024
#
# Жесткий дедлайн: 23:59MSK 24.12.2024
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **10.75 баллов + 4 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется
#
# ### О задании
#
# В этом задании вам предстоит воспользоваться возможностями bootstraping для оценки смещения и разброса алгоритмов машинного обучения. Делать мы это будем на данных boston.
# Также в задании вам будет предложено пообучать готовые модели градиентного бустинга и CatBoost.

# %% [markdown]
# **Напоминание:**
#
# * Все ваши графики должны быть **"красивыми"** --- подробнее о том, как их оформлять, можно найти в первом практическом задании. При несоответствии какиму-то из критериев вам могут снять баллы.
# * Пишите в текстовых ячейках/print в коде ответы на **все вопросы из заданий/просьбы сделать выводы** --- при их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и поэтому будем снижать баллы

# %% [markdown]
# # Часть 1. Bias-Variance Decomposition

# %%
import numpy as np
import pandas as pd
import warnings
from matplotlib import pyplot as plt
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]

X
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# ### Вычисление bias и variance с помощью бутстрапа
# На лекции была выведено следующая формула, показывающая, как можно представить ошибку алгоритма регрессии в виде суммы трех компонент:
# $$
# L(\mu) =
#     \mathbb{E}_{x, y}\bigl[\mathbb{E}_{X}\bigl[ (y - \mu(X)(x))^2 \bigr]\bigr] =
# $$
# $$
#     \underbrace{\mathbb{E}_{x, y}\bigl[(y - \mathbb{E}[y|x] )^2\bigr]}_{\text{шум}} + \underbrace{\mathbb{E}_{x}\bigl[(\mathbb{E}_{X}[\mu(X)(x)] - \mathbb{E}[y|x] )^2\bigr]}_{\text{смещение}} +
#     \underbrace{\mathbb{E}_{x}\bigl[\mathbb{E}_{X}\bigl[(\mu(X)(x) - \mathbb{E}_{X}[\mu(X)(x)] )^2\bigr]\bigr]}_{\text{разброс}},
# $$
# * $\mu(X)$ — алгоритм, обученный по выборке $X = \{(x_1, y_1), \dots (x_\ell, y_\ell)\}$;
# * $\mu(X)(x)$ — ответ алгоритма, обученного по выборке $X$, на объекте $x$;
# * $\mathbb{E}_{X}$ — мат. ожидание по всем возможным выборкам;
# * $\mathbb{E}_{X}[\mu(X)(x)]$ — "средний" ответ алгоритма, обученного по всем возможным выборкам $X$, на объекте $x$.
#
# С помощью этой формулы мы можем анализировать свойства алгоритма обучения модели $\mu$, если зададим вероятностную модель порождения пар $p(x, y)$.
#
# В реальных задачах мы, конечно же, не знаем распределение на парах объект - правильный ответ. Однако у нас есть набор семплов из этого распределения (обучающую выборка), и мы можем использовать его, чтобы оценивать математические ожидания. Для оценки мат. ожиданий по выборкам мы будем пользоваться бутстрэпом - методом генерации "новых" выборок из одной с помощью выбора объектов с возвращением. Разберем несколько шагов на пути к оценке смещения и разброса.
#
# #### Приближенное вычисление интегралов
# На занятиях мы разбирали примеры аналитического вычисления смещения и разброса нескольких алгоритмов обучения. Для большинства моделей данных и алгоритмов обучения аналитически рассчитать математические ожидания в формулах не удастся. Однако мат. ожидания можно оценивать приближенно. Чтобы оценить математическое ожидание $\mathbb{E}_{\bar z} f(\bar z)$ функции от многомерной случайной величины $\bar z = (z_1, \dots, z_d)$, $\bar z \sim p(\bar z)$, можно сгенерировать выборку из распределения $p(\bar z)$ и усреднить значение функции на элементах этой выборки:
# $$\mathbb{E}_{\bar z} f(z) = \int f(\bar z) p(\bar z) d \bar z \approx \frac 1 m \sum_{i=1}^m f(\bar z_i), \, \bar z_i \sim p(\bar z), i = 1, \dots, m.$$
#
# Например, оценим $\mathbb{E}_z z^2,$ $z \sim \mathcal{N}(\mu=5, \sigma=3)$ (из теории вероятностей мы знаем, что
# $\mathbb{E}_z z^2 = \sigma^2 + \mu^2 = 34$):

# %%
z = np.random.normal(loc=5, scale=3, size=1000)
(z**2).mean()
# Out:
# 33.3454437583616

# %% [markdown]
# #### Оценивание $\mathbb{E}_{x, y}$
# Оценить мат. ожидания по $x$ и по $x, y$, встречающиеся во всех трех компонентах разложения, несложно, потому что у нас есть выборка объектов из распределения данных $p(x, y)$:
# $$ \mathbb{E}_{x} f(x) \approx \frac 1 N \sum_{i=1}^N f(x_i), \quad
# \mathbb{E}_{x, y} f(x, y) \approx \frac 1 N \sum_{i=1}^N f(x_i, y_i),$$
# где $N$ - число объектов в выборке, $\{(x_i, y_i)\}_{i=1}^N$ - сама выборка.
#
# #### Оценивание $\mathbb{E}_X$ с помощью бутстрапа
# Чтобы оценить мат. ожидание по $X$, нам понадобится выборка из выборок:
# $$\mathbb{E}_X f(X) \approx \frac 1 s \sum_{j=1}^s f(X_j),$$
# где $X_j$ - $j$-я выборка. Чтобы их получить, мы можем воспользоваться бутстрапом - методом генерации выборок на основе выбора объектов с возвращением. Чтобы составить одну выборку, будем $N$ раз выбирать индекс объекта $i \sim \text{Uniform}(1 \dots N)$ и добавлять $i$-ю пару (объект, целевая переменная) в выборку. В результате в каждой выборке могут появиться повторяющиеся объекты, а какие-то объекты могут вовсе не войти в некоторые выборки.
#
# #### Итоговый алгоритм оценки смещения и разброса алгоритма $a$
# 1. Сгенерировать $s$ выборок $X_j$ методом бутстрапа.
# 1. На каждой выборке $X_j$ обучить алгоритм $a_j$.
# 1. Для каждой выборки $X_j$ определить множество объектов $T_j$, не вошедших в нее (out-of-bag). Вычислить предсказания алгоритма $a_j$ на объектах $T_j$.
#
# Поскольку у нас есть только один ответ для каждого объекта, мы будем считать шум равным 0, а $\mathbb{E}[y|x]$ равным имеющемуся правильному ответу для объекта $x$.
#
# Итоговые оценки:
# * Смещение: для одного объекта - квадрат разности среднего предсказания и правильного ответа. Среднее предсказание берется только по тем алгоритмам $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего смещения выполнить усреденение смещений по объектам.
# * Разброс: для одного объекта - выборочная дисперсия предсказаний алгоритмов $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего разброса выполнить усреденение разбросов по объектам.
# * Ошибка $L$: усреднить квадраты разностей предсказания и правильного ответа по всем выполненным предсказаниям для всех объектов.
#
# В результате должно получиться, что ошибка приблизительно равна сумме смещения и разброса!
#
# Алгоритм также вкратце описан по [ссылке](https://web.engr.oregonstate.edu/~tgd/classes/534/slides/part9.pdf) (слайды 19-21).
#
# __Задание 1. (1.5 баллa)__
#
# Реализуйте описанный алгоритм. Обратите внимание, что если объект не вошел ни в одну из out-of-bag выборок, учитывать его в вычислении итоговых величин не нужно. Как обычно, разрешается использовать только один цикл - по выборкам (от 0 до num_runs-1).

# %%
def compute_biase_variance(regressor, X, y, num_runs=1000):
    """
    :param regressor: sklearn estimator with fit(...) and predict(...) method
    :param X: numpy-array representing training set ob objects, shape [n_obj, n_feat]
    :param y: numpy-array representing target for training objects, shape [n_obj]
    :param num_runs: int, number of samples (s in the description of the algorithm)

    :returns: bias (float), variance (float), error (float)
    each value is computed using bootstrap
    """
    n_samples = X.shape[0]
    sum_preds = np.zeros(n_samples)
    sum_preds_sq = np.zeros(n_samples)
    counts = np.zeros(n_samples, dtype=int)
    total_error = 0
    total_count = 0
    for run in range(num_runs):
        indices = resample(np.arange(n_samples), replace=True, n_samples=n_samples, random_state=None)
        reg = clone(regressor)
        reg.fit(X[indices], y[indices])
        oob_indices = np.setdiff1d(np.arange(n_samples), indices)
        if oob_indices.size == 0:
            continue
        y_pred = reg.predict(X[oob_indices])
        sum_preds[oob_indices] += y_pred
        sum_preds_sq[oob_indices] += y_pred ** 2
        counts[oob_indices] += 1
        total_error += np.sum((y_pred - y[oob_indices]) ** 2)
        total_count += oob_indices.size
    valid = counts > 0
    mean_preds = sum_preds[valid] / counts[valid]
    bias = np.mean((mean_preds - y[valid]) ** 2)
    variance = np.mean((sum_preds_sq[valid] / counts[valid]) - (mean_preds ** 2))
    error = total_error / total_count
    return bias, variance, error

# %% [markdown]
# **Задание 2. (0.5 баллa)**
#
# **(0.3 балла)** Оцените смещение, разброс и ошибку для трех алгоритмов с гиперпараметрами по умолчанию: линейная регрессия, решающее дерево, случайный лес.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.utils import resample
from sklearn.base import clone

regressors = {
    "Линейная регрессия": LinearRegression(),
    "Решающее дерево": DecisionTreeRegressor(),
    "Случайный лес": RandomForestRegressor()
}

num_runs = 1000

print(f"{'Модель':<20} {'Смещение':<15} {'Разброс':<15} {'Ошибка':<15} {'Смещение+Разброс':<20}")
print("-" * 85)

for name, reg in regressors.items():
    bias, variance, error = compute_biase_variance(reg, X, y, num_runs=num_runs)
    print(f"{name:<20} {bias:<15.4f} {variance:<15.4f} {error:<15.4f} {bias + variance:<20.4f}")
# Out:
# Модель               Смещение        Разброс         Ошибка          Смещение+Разброс
# -------------------------------------------------------------------------------------
# Линейная регрессия   23.8106         0.9641          24.7864         24.7748
# Решающее дерево      9.9945          12.9677         22.9650         22.9622
# Случайный лес        10.6790         2.2685          12.9537         12.9475

# %% [markdown]
# **(0.1 балл) (?)** Проанализируйте полученный результат. Согласуются ли полученные результаты с теми, что мы обсуждали на семинарах (с комментарием)?
#
# __Your answer here:__ Линейная регрессия демонстрирует тенденцию, при которой высокая ошибка обусловлена преимущественно большим смещением. Решающее дерево показывает компромисс между смещением и разбросом, однако общий уровень ошибки остается достаточно высоким. Случайный лес подтверждает свои преимущества: он обладает сниженным разбросом и представляет собой более сбалансированную модель с минимальной ошибкой среди всех представленных.
#
# **(0.1 балл) (?)** Вспомните во сколько раз в теории бутстрап уменьшает разброс базового алгоритма. Выполняется ли это в ваших экспериментах? Если нет, поясните, почему.
#
# __Your answer here:__ В теории бутстрап уменьшает разброс базового алгоритма примерно в $\sqrt{n}$ раз, где n — количество деревьев. В эксперименте разброс решающего дерева составляет 12.9677, а случайного леса — 2.2685, что дает уменьшение примерно в 5.72 раза, меньше теоретического значения для n = 100. Это отклонение связано с коррелированностью деревьев из-за перекрытия бутстрап-выборок и ограниченным числом деревьев. Тем не менее, уменьшение разброса подтверждает преимущество ансамблирования.

# %% [markdown]
# ### Визуализация предсказаний базовых алгоритмов бэггинга
#
# В материалах лекций можно найти изображение, похожее на мишень - визуализация алгоритмов с разным смещением и разным разбросом. В центре "мишени" - правильный ответ, а "попадания" - предсказания алгоритмов, обученных по разным выборкам. Построим похожее изображение на наших данных для трех алгоритмов. Наши "мишени" будут одномерными, потому что мы решаем задачу одномерной регрессии.
#
# __Задание 3. (1.25 балла)__
#
# **(0.5 балла)** Реализуйте фукнцию plot_predictions. Она должна выполнять следующие действия:
# 1. Случайно выбрать num_test_objects пар объект-целевая переменная из выборки X, y. Получится две выборки: маленькая X_test, y_test (выбранные тестовые объекты) и X_train, y_train (остальные объекты).
# 1. Сгенерировать num_runs выборок методом бутстарапа из X_train, y_train. На каждой выборке обучить алгоритм regressor и сделать предсказания для X_test.
# 1. Нарисовать scatter-график. По оси абсцисс - объекты тестовой выборки (номера от 0 до num_test_objects-1), по оси ординат - предсказания для каждого из num_runs выборок. В итоге получится num_test_objects столбиков с точками. Для каждого тестового объекта надо отметить одним цветом (в рамках каждого номера объекта, т.е. предсказания для объектов с одинаковым номером -- одинаковым цветом, а с разными -- разными цветами) все предсказания для него, а также черным цветом отметить правильный ответ.
# 1. Подпишите оси и название графика (аргумент title).

# %%
def plot_predictions(regressor, X, y, num_runs=100, num_test_objects=10, title=""):
    """
    plot graphics described above
    """
    n_samples = X.shape[0]
    test_indices = np.random.choice(n_samples, size=num_test_objects, replace=False)
    train_indices = np.setdiff1d(np.arange(n_samples), test_indices)
    X_test, y_test, X_train, y_train = X[test_indices], y[test_indices], X[train_indices], y[train_indices]
    predictions = np.zeros((num_runs, num_test_objects))

    for run in range(num_runs):
        bootstrap_indices = resample(np.arange(X_train.shape[0]), replace=True, n_samples=X_train.shape[0])
        reg = clone(regressor)
        reg.fit(X_train[bootstrap_indices], y_train[bootstrap_indices])
        y_pred = reg.predict(X_test)
        predictions[run] = y_pred
    plt.figure(figsize=(12, 6))
    cmap = plt.get_cmap('tab20')
    colors = [cmap(i) for i in range(num_test_objects)]
    for i in range(num_test_objects):
        x_values = np.full(num_runs, i)
        y_values = predictions[:, i]
        plt.scatter(x_values, y_values, color=colors[i], alpha=0.6, label=f'Object {i}' if i < 10 else None)
    plt.scatter(np.arange(num_test_objects), y_test, color='black', marker='x', s=100, label='True Value')
    plt.xlabel('Индекс тестового объекта')
    plt.ylabel('Предсказанное значение')
    plt.title(title)
    plt.xticks(np.arange(num_test_objects))
    if num_test_objects <= 10:
        plt.legend()
    else:
        handles, labels = plt.gca().get_legend_handles_labels()
        plt.legend(handles[:10] + handles[-1:], labels[:10] + ['True Value'], loc='upper right', bbox_to_anchor=(1.15, 1))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **(0.25 баллa)** Нарисуйте графики для линейной регрессии, решающего дерева и случайного леса. Нарисуйте три графика в строчку (это можно сделать с помощью plt.subplot) с одинаковой осью ординат (это важно для понимания масштаба разброса у разных алгоритмов):

# %%
### your code here ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **(0.5 балла) (?)** Для каждого графика прокомментируйте, как он характеризует смещение и разброс соответствующего алгоритма.
#
# **Your answer here:**

# %% [markdown]
# # Часть 2. Градиентный бустинг

# %% [markdown]
# **Задание 4 (1 балл)**
#
# Мы будем использовать данные из [соревнования](https://www.kaggle.com/t/b710e05dc0bd424995ca94da5b639869) (вам нужны только данные, посылать туда ничего не надо).
# * Загрузите таблицу application_train.csv;
# * Запишите в Y столбец с целевой переменной (TARGET);
# * Определите дисбаланс классов
# * Определите тип столбцов и заполните пропуски - стратегия произвольная;
# * Разбейте выборку в соотношении 70:30 с random_state=0. Если считаете нужным, сделайте сбалансированное по классам разбиение.
# * Допишите функцию score_model для обучения и оценки качества модели
#
# Так как в данных имеется значительный дисбаланс классов, в качестве метрики качества везде будем использовать площадь под precision-recall кривой (AUC-PR).

# %%
import time
from sklearn.metrics import precision_recall_curve, auc
def score_model(model, X_train, X_test, y_train, y_test, print_res: bool = True, **fit_kwargs):
    """
    :param model: обучаемая модель
    :param print_res: Если True, то результат выполнения выводится в консоль

    :return: Если print_res == False, то функция возвращает словарь с ключами 'pr-auc' и 'fit-time'
    """
    start_time = time.time()
    model.fit(X_train, y_train, **fit_kwargs)
    fit_time = time.time() - start_time
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    pr_auc = auc(recall, precision)
    if print_res:
        print(f"pr-auc = {pr_auc:.4f}\tfit time = {fit_time:.4f} s")
    else:
        return {'pr-auc': pr_auc, 'fit-time': fit_time}

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

data = pd.read_csv('application_train.csv')

Y = data['TARGET']
X = data.drop(columns=['TARGET'])

class_counts = Y.value_counts(normalize=True)
print(class_counts)

categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(exclude=['object']).columns

imputer_categorical = SimpleImputer(strategy='most_frequent')
imputer_numerical = SimpleImputer(strategy='mean')

X[categorical_cols] = imputer_categorical.fit_transform(X[categorical_cols])
X[numerical_cols] = imputer_numerical.fit_transform(X[numerical_cols])

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, random_state=0, stratify=Y
)
# Out:
# TARGET
# 0    0.919111
# 1    0.080889
# Name: proportion, dtype: float64

# %% [markdown]
# **Задание 5 (1 балл)**

# %% [markdown]
# **(0.7 баллa)** Обучите реализации градиентного бустинга LightGBM и Catboost на вещественных признаках без подбора параметров.
#
# **(0.3 баллa) (?) Получилась ли заметная разнциа в качестве? Как вы думаете, почему?**
#
# **Замечание:**
# * В этом и последующих экспериментах необходимо измерять время обучения моделей.

# %%
! pip install lightgbm catboost
# Out:
# Requirement already satisfied: lightgbm in d:\anaconda\envs\env\lib\site-packages (4.5.0)
# Requirement already satisfied: catboost in d:\anaconda\envs\env\lib\site-packages (1.2.7)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda\envs\env\lib\site-packages (from lightgbm) (1.24.3)
# Requirement already satisfied: scipy in d:\anaconda\envs\env\lib\site-packages (from lightgbm) (1.10.1)
# Requirement already satisfied: graphviz in d:\anaconda\envs\env\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\env\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: pandas>=0.24 in d:\anaconda\envs\env\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: plotly in d:\anaconda\envs\env\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in d:\anaconda\envs\env\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\env\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\env\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\env\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\anaconda\envs\env\lib\site-packages (from matplotlib->catboost) (6.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\envs\env\lib\site-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda\envs\env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.17.0)

# %%
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score

X_train_float = X_train.select_dtypes(include=['float64', 'int64'])
X_test_float = X_test.select_dtypes(include=['float64', 'int64'])

score_model(lgb.LGBMClassifier(random_state=0), X_train_float, X_test_float, y_train, y_test)
score_model(CatBoostClassifier(silent=True, random_state=0), X_train_float, X_test_float, y_train, y_test)
# Out:
# [LightGBM] [Info] Number of positive: 12188, number of negative: 138491
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012771 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11407
# [LightGBM] [Info] Number of data points in the train set: 150679, number of used features: 100
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.080887 -> initscore=-2.430353
# [LightGBM] [Info] Start training from score -2.430353
# pr-auc = 0.2274	fit time = 1.4604 s
# pr-auc = 0.2314	fit time = 20.7291 s

# %% [markdown]
# **Your answer here:** Разница в качестве минимальна из-за использования только вещественных признаков и стандартных параметров. Однако LightGBM оказался значительно быстрее, что делает его предпочтительнее.

# %% [markdown]
# __Задание 6. (1 балл)__
#
# **(0.5 баллa)** Подберите оптимальные с точки зрения метрики качества параметры алгоритмов, изменяя:
#
# * глубину деревьев;
# * количество деревьев;
# * темп обучения;
#
# Масштаб значений предлагается посмотреть [тут](https://github.com/esokolov/ml-course-hse/blob/master/2019-fall/seminars/sem10-gbm.ipynb).
#
# **(0.5 баллa) (?)** Проанализируйте соотношения получившихся оптимальных глубины и количества деревьев в зависимости от алгоритма.**
#
# **Если на перебор гиперпараметров уходит много времени, то переберите значениях каких-нибудь 1-2 гиперпараметров, а не всех предложенных 3**

# %%
n_trees = [1, 5, 10, 100, 200, 300, 400, 500, 600, 700]
depth_lgbm = list(range(1, 30, 3))
depth_cat = list(range(1, 12, 2))
lgbm_scores = {}
cat_scores = {}
lgbm_time = {}
cat_time = {}
for n_tree in n_trees:
    results = score_model(lgb.LGBMClassifier(n_estimators=n_tree, random_state=0, verbose=-1), X_train_float, X_test_float, y_train, y_test, print_res=False)
    lgbm_scores[n_tree] = results['pr-auc']
    lgbm_time[n_tree] = results['fit-time']
    results = score_model(CatBoostClassifier(n_estimators=n_tree, silent=True, random_state=0), X_train_float, X_test_float, y_train, y_test, print_res=False)
    cat_scores[n_tree] = results['pr-auc']
    cat_time[n_tree] = results['fit-time']

# %%
plt.figure(figsize=(10, 5))
plt.plot(lgbm_scores.keys(), lgbm_scores.values(), marker='o', label="LGBM")
plt.plot(cat_scores.keys(), cat_scores.values(), marker='o', label="CatBoost")
plt.title("PR-AUC в зависимости от n_trees")
plt.xlabel("n_trees")
plt.ylabel("PR-AUC")
plt.legend()
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(lgbm_time.keys(), lgbm_time.values(), marker='o', label="LGBM")
plt.plot(cat_time.keys(), cat_time.values(), marker='o', label="CatBoost")
plt.title("Training time в зависимости от n_trees")
plt.xlabel("n_trees")
plt.ylabel("Training time (in seconds)")
plt.legend()
plt.grid(True)
plt.legend()
plt.show()

# %%
cat_best_n_tree = 700
lgbm_best_n_tree = 100

# %%
lgbm_scores = {}
cat_scores = {}
lgbm_time = {}
cat_time = {}
for depth in depth_lgbm:
    results = score_model(lgb.LGBMClassifier(n_estimators=lgbm_best_n_tree, depth=depth, random_state=0, verbose=-1), X_train_float, X_test_float, y_train, y_test, print_res=False)
    lgbm_scores[depth] = results['pr-auc']
    lgbm_time[depth] = results['fit-time']
for depth in depth_cat:
    results = score_model(CatBoostClassifier(n_estimators=cat_best_n_tree, depth=depth, silent=True, random_state=0), X_train_float, X_test_float, y_train, y_test, print_res=False)
    cat_scores[depth] = results['pr-auc']
    cat_time[depth] = results['fit-time']

# %%
plt.figure(figsize=(10, 5))
plt.plot(lgbm_scores.keys(), lgbm_scores.values(), marker='o', label="LGBM")
plt.plot(cat_scores.keys(), cat_scores.values(), marker='o', label="CatBoost")
plt.title("PR-AUC в зависимости от depth")
plt.xlabel("depth")
plt.ylabel("PR-AUC")
plt.legend()
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(lgbm_time.keys(), lgbm_time.values(), marker='o', label="LGBM")
plt.plot(cat_time.keys(), cat_time.values(), marker='o', label="CatBoost")
plt.title("Training time в зависимости от depth")
plt.xlabel("depth")
plt.ylabel("Training time (in seconds)")
plt.legend()
plt.grid(True)
plt.legend()
plt.show()

# %%
cat_best_depth = max(cat_scores, key=cat_scores.get)
lgbm_best_depth = max(lgbm_scores, key=lgbm_scores.get)
print(f"CatBoost best depth: {cat_best_depth}")
print(f"LGBM best depth: {lgbm_best_depth}")
# Out:
# CatBoost best depth: 3
# LGBM best depth: 1

# %% [markdown]
# **Your answer here:** CatBoost использует умеренную глубину деревьев и большее количество, что типично для задач, где модель пытается сбалансировать смещение и разброс. LightGBM, напротив, использует очень мелкие деревья и меньшее число деревьев, что говорит о его агрессивной оптимизации и высокой скорости сходимости.

# %% [markdown]
# **Задание 7 (1 баллa)**
#
# **(0.5 баллов)** Добавьте категориальные признаки к вещественным следующими способами:
#
# * как OHE признаки;
# * как счетчики со сглаживанием.
#
# Можно использовать библиотечные реализации; при подсчете счетчиков нельзя использовать циклы.
#
# **Замечание**: среди признаков с типом object есть несколько бинарных, все остальные --- категориальные
#
# **(0.5 баллa) (?)** Как меняется время, необходимое для обучения моделей в зависимости от способа кодирования? (Параметры можно не подбирать).

# %%
cat_features = [col for col in X.columns if (X[col].nunique() > 2 and X[col].dtype == 'object')]

bin_features = [col for col in X.columns if X[col].nunique() == 2]

new_bin_features = [col for col in X.columns if (X[col].nunique() == 2 and X[col].dtype == 'object')]

print('Categorical:', *cat_features)
print('Binary:', *bin_features)
print('Binary objects:', *new_bin_features)
# Out:
# Categorical: CODE_GENDER NAME_TYPE_SUITE NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS NAME_HOUSING_TYPE OCCUPATION_TYPE WEEKDAY_APPR_PROCESS_START ORGANIZATION_TYPE FONDKAPREMONT_MODE HOUSETYPE_MODE WALLSMATERIAL_MODE
# Binary: NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY FLAG_MOBIL FLAG_EMP_PHONE FLAG_WORK_PHONE FLAG_CONT_MOBILE FLAG_PHONE FLAG_EMAIL REG_REGION_NOT_LIVE_REGION REG_REGION_NOT_WORK_REGION LIVE_REGION_NOT_WORK_REGION REG_CITY_NOT_LIVE_CITY REG_CITY_NOT_WORK_CITY LIVE_CITY_NOT_WORK_CITY EMERGENCYSTATE_MODE FLAG_DOCUMENT_2 FLAG_DOCUMENT_3 FLAG_DOCUMENT_4 FLAG_DOCUMENT_5 FLAG_DOCUMENT_6 FLAG_DOCUMENT_7 FLAG_DOCUMENT_8 FLAG_DOCUMENT_9 FLAG_DOCUMENT_10 FLAG_DOCUMENT_11 FLAG_DOCUMENT_12 FLAG_DOCUMENT_13 FLAG_DOCUMENT_14 FLAG_DOCUMENT_15 FLAG_DOCUMENT_16 FLAG_DOCUMENT_17 FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21
# Binary objects: NAME_CONTRACT_TYPE FLAG_OWN_CAR FLAG_OWN_REALTY EMERGENCYSTATE_MODE

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct_ohe = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(), cat_features + bin_features)
    ],
    remainder='passthrough'
)

ct_ohe.fit(X)
X_train_ohe = ct_ohe.transform(X_train)
X_test_ohe = ct_ohe.transform(X_test)

X_train_ohe.shape, X_train.shape
# Out:
# ((150679, 277), (150679, 121))

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from collections import defaultdict

# %%
class SmoothMeanTargetEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, rand_coef = 0.01, C = 5):
        self.rand_coef = rand_coef
        self.C = C

    def get_feature_names_out(self, input_features):
        return input_features

    def fit(self, X, y):
        self.maps = defaultdict(lambda: defaultdict(float))
        self.glob_mean = y.mean()
        for col in X.columns:
            self.maps[col] = (y.groupby(X[col]).sum() + self.C * self.glob_mean) / (y.groupby(X[col]).count() + self.C)
        return self

    def transform(self, X):
        X_new = X.copy()
        for col in X.columns:
            X_new[col] = X_new[col].map(self.maps[col]) + np.random.normal(0, self.rand_coef, X_new[col].shape)
        return X_new

# %%
ct_smte = ColumnTransformer(
    transformers=[
        ('smte', SmoothMeanTargetEncoder(), cat_features + bin_features)
    ],
    remainder='passthrough'
)

ct_smte.fit(X, Y)
X_train_smte = ct_smte.transform(X_train)
X_test_smte = ct_smte.transform(X_test)

X_train_smte.shape, X_train.shape
# Out:
# ((150679, 121), (150679, 121))

# %%
lgbm_scores = {}
cat_scores = {}
lgbm_time = {}
cat_time = {}
results = score_model(lgb.LGBMClassifier(n_estimators=lgbm_best_n_tree, depth=lgbm_best_depth, random_state=0, verbose=-1), X_train_float, X_test_float, y_train, y_test, print_res=False)
lgbm_scores['without_categories'] = results['pr-auc']
lgbm_time['without_categories'] = results['fit-time']
results = score_model(CatBoostClassifier(n_estimators=cat_best_n_tree, depth=cat_best_depth, silent=True, random_state=0), X_train_float, X_test_float, y_train, y_test, print_res=False)
cat_scores['without_categories'] = results['pr-auc']
cat_time['without_categories'] = results['fit-time']

# %%
results = score_model(lgb.LGBMClassifier(n_estimators=lgbm_best_n_tree, depth=lgbm_best_depth, random_state=0, verbose=-1), X_train_ohe, X_test_ohe, y_train, y_test, print_res=False)
lgbm_scores['OHE'] = results['pr-auc']
lgbm_time['OHE'] = results['fit-time']
results = score_model(CatBoostClassifier(n_estimators=cat_best_n_tree, depth=cat_best_depth, silent=True, random_state=0), X_train_ohe, X_test_ohe, y_train, y_test, print_res=False)
cat_scores['OHE'] = results['pr-auc']
cat_time['OHE'] = results['fit-time']

# %%
results = score_model(lgb.LGBMClassifier(n_estimators=lgbm_best_n_tree, depth=lgbm_best_depth, random_state=0, verbose=-1), X_train_smte, X_test_smte, y_train, y_test, print_res=False)
lgbm_scores['SMTE'] = results['pr-auc']
lgbm_time['SMTE'] = results['fit-time']
results = score_model(CatBoostClassifier(n_estimators=cat_best_n_tree, depth=cat_best_depth, silent=True, random_state=0), X_train_smte, X_test_smte, y_train, y_test, print_res=False)
cat_scores['SMTE'] = results['pr-auc']
cat_time['SMTE'] = results['fit-time']

# %%
categories = list(lgbm_scores.keys())
x = np.arange(len(categories))
width = 0.35

plt.figure(figsize=(10, 6))
plt.bar(x - width / 2, lgbm_scores.values(), width, label='LGBM PR-AUC')
plt.bar(x + width / 2, cat_scores.values(), width, label='CatBoost PR-AUC')
plt.xticks(x, categories)
plt.ylabel('PR-AUC')
plt.title('Сравнение PR-AUC для разных подходов кодирования категорий')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(x - width / 2, lgbm_time.values(), width, label='LGBM Time')
plt.bar(x + width / 2, cat_time.values(), width, label='CatBoost Time')
plt.xticks(x, categories)
plt.ylabel('Время обучения (сек)')
plt.title('Сравнение времени обучения для разных подходов кодирования категорий')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

for key in categories:
    print('PR-AUC score for LGBM + ', key, ':', lgbm_scores[key])
    print('PR-AUC score for CatBoost + ', key, ':', cat_scores[key])

for key in categories:
    print('Training time for LGBM + ', key, ':', lgbm_time[key])
    print('Training time for CatBoost + ', key, ':', cat_time[key])
# Out:
# PR-AUC score for LGBM +  without_categories : 0.2273515473270673
# PR-AUC score for CatBoost +  without_categories : 0.23216532113415708
# PR-AUC score for LGBM +  OHE : 0.22984261571113385
# PR-AUC score for CatBoost +  OHE : 0.23771292968247804
# PR-AUC score for LGBM +  SMTE : 0.2273759196084869
# PR-AUC score for CatBoost +  SMTE : 0.2330002795592458
# Training time for LGBM +  without_categories : 1.202906608581543
# Training time for CatBoost +  without_categories : 8.739229679107666
# Training time for LGBM +  OHE : 1.5193660259246826
# Training time for CatBoost +  OHE : 18.184011459350586
# Training time for LGBM +  SMTE : 2.2712268829345703
# Training time for CatBoost +  SMTE : 10.844053506851196

# %% [markdown]
# **Your answer here:** Для CatBoost OHE дает наибольший прирост качества, но время обучения возрастает более чем в 2 раза. SMTE также улучшает качество, но с меньшим эффектом и меньшим ростом времени. Для LGBM влияние OHE и SMTE на качество минимально, однако они значительно увеличивают время обучения.

# %% [markdown]
# **Задание 8 (1 балл)**
#
# **(0.7 баллa)** Для CatBoost можно не делать ручную обработку категориальных признаков, а подавать как есть. Обучите модель CatBoost, не обрабатывая специально категориальные признаки, замерьте время обучения (параметры возьмите из предыдущего пункта).
#
# **(0.3 баллa) (?)** Сравните с временем обучения модели CatBoost из предыдущего пункта. Как изменилось время? Почему?

# %%
column_indices = [X.columns.get_loc(col) for col in cat_features + new_bin_features]

score_model(CatBoostClassifier(n_estimators=cat_best_n_tree, depth=cat_best_depth, silent=True, random_state=0),
            X_train, X_test, y_train, y_test, print_res=True, cat_features=column_indices)
# Out:
# pr-auc = 0.2386	fit time = 47.0539 s

# %% [markdown]
# **Your answer here:** CatBoost обрабатывает категориальные признаки динамически, рассчитывая для каждой категории на разных стадиях построения деревьев. Это требует дополнительных операций и вычислений, что увеличивает время обучения по сравнению с заранее выполненной обработкой

# %% [markdown]
# **Бонус. (1 балл)**
#
# **(0.7 баллa)** Подберите оптимальные параметры для LightGBM с вещественными и категориальными признаками (предварительно обработанные каким-нибудь способом). Подберите оптимальные параметры для CatBoost с вещественными и необработанными категориальными признаками.
#
# **(0.3 баллa) (?)** Сравните качество моделей на наилучших параметрах. Какой метод получился лучше с точки зрения качества? Совпадает ли результат с вашими ожиданиями?

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, precision_recall_curve, auc

def pr_auc_score(y_true, y_pred_proba):
    precision, recall, _ = precision_recall_curve(y_true, y_pred_proba)
    return auc(recall, precision)

pr_auc = make_scorer(pr_auc_score, needs_proba=True)

n_trees = [200, 400, 700]
depth_lgbm = list(range(1, 30, 3))
depth_cat = list(range(1, 12, 2))
learning_rates = [0.01, 0.05, 0.1, 0.3]

param_grid = {
    'n_estimators': n_trees,
    'depth': depth_cat,
    'learning_rate': learning_rates
}

# %%
model = CatBoostClassifier(silent=True, random_state=0, cat_features=column_indices)

cat_grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring=pr_auc,
    cv=3,
    verbose=1,
    n_jobs=-1
)

cat_grid_search.fit(X_train, y_train)

print("Лучшие параметры CatBoost:", cat_grid_search.best_params_)
print("Лучший PR-AUC для CatBoost:", cat_grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# Лучшие параметры CatBoost: {'depth': 5, 'learning_rate': 0.05, 'n_estimators': 700}
# Лучший PR-AUC для CatBoost: 0.24136455214297403

# %%
lgbm_model = lgb.LGBMClassifier(random_state=0, verbose=-1)

param_grid = {
    'n_estimators': n_trees,
    'depth': depth_lgbm,
    'learning_rate': learning_rates
}

lgbm_grid_search = GridSearchCV(
    estimator=lgbm_model,
    param_grid=param_grid,
    scoring=pr_auc,
    cv=3,
    verbose=1,
    n_jobs=-1
)

lgbm_grid_search.fit(X_train_smte, y_train)

print("Лучшие параметры LGBM:", lgbm_grid_search.best_params_)
print("Лучший PR-AUC для LGBM:", lgbm_grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Лучшие параметры LGBM: {'depth': 1, 'learning_rate': 0.01, 'n_estimators': 700}
# Лучший PR-AUC для LGBM: 0.23383832224280243

# %%
! pip install dill
# Out:
# Collecting dill
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Installing collected packages: dill
# Successfully installed dill-0.3.9

# %%
import dill

# %%
dill.load_session('session1.db')

# %%
best_lgbm_model = lgb.LGBMClassifier(depth=1, learning_rate=0.01, n_estimators=700, random_state=0, verbose=-1)
best_cat_model = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=0)

# %%
score_model(best_cat_model, X_train, X_test, y_train, y_test, print_res=True, cat_features=column_indices)
# Out:
# pr-auc = 0.2394	fit time = 86.6856 s

# %%
score_model(best_lgbm_model, X_train_smte, X_test_smte, y_train, y_test, print_res=True)
# Out:
# pr-auc = 0.2342	fit time = 12.0557 s

# %% [markdown]
# Ответ: CatBoost продемонстрировал лучшее качество модели по сравнению с LightGBM, однако LightGBM обучается значительно быстрее. Результаты соответствуют ожиданиям: CatBoost обеспечивает преимущество в качестве за счет увеличенного времени обучения.

# %% [markdown]
# # Часть 3. Отбор признаков

# %% [markdown]
# В данном разделе вам предстоит познакомиться с методами отбора признаков. Вы узнаете как определяется важность признаков для различных классов моделей. Проверите, совпадают ли наиболее важные признаки при различных стратегиях отбора.
#
# В данном разделе, помимо градиентных бустингов, будут рассматриваться и линейные модели. В качестве представителя класса градиентных бустингов возьмем Catboost. В качестве представителя класса линейных моделей возьмем LogReg
#
# Обучите базовые модели (catboost и logreg). При обучении logreg используйте гиперпараметры: $C=10^2, \text{max_iter}=1\,000$.
#
# **Важно**: установите random seed = 73 для всех методов!
#
# **Важно**: не забудте про StandardScaler при обучении линейной модели

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

import seaborn as sns

# %%
def print_results(fit_results: dict, model_name: str, base_score: float = None):
    pr_aur = fit_results['pr-auc']
    fit_time = fit_results['fit-time']

    if base_score is not None:
        print(f"{model_name:12}:\t\tpr-auc: {pr_aur:.4f}\tdeviation: {pr_aur - base_score:.4f}\tfit_time: {fit_time:.3} s")
    else:
        print(f"{model_name:12}:\t\tpr-auc: {pr_aur:.4f}\tfit_time: {fit_time:.3} s")

    return fit_results

# %%
from sklearn.preprocessing import OrdinalEncoder

numeric_features = numerical_cols
np.random.seed(73)
ct = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_features),
    ('scaler', StandardScaler(), numeric_features),
    ('binarizer', OrdinalEncoder(), new_bin_features)
], verbose_feature_names_out=False)
ct.set_output(transform='pandas')

ct.fit(X)
X_train_pr = ct.transform(X_train)
X_test_pr =  ct.transform(X_test)

X_train_pr.head()
# Out:
#         CODE_GENDER_F  CODE_GENDER_M  CODE_GENDER_XNA  \
# 154638            1.0            0.0              0.0
# 167190            1.0            0.0              0.0
# 121322            1.0            0.0              0.0
# 67133             0.0            1.0              0.0
# 150061            0.0            1.0              0.0
#
#         NAME_TYPE_SUITE_Children  NAME_TYPE_SUITE_Family  \
# 154638                       0.0                     0.0
# 167190                       0.0                     0.0
# 121322                       0.0                     0.0
# 67133                        0.0                     0.0
# 150061                       0.0                     0.0
#
#         NAME_TYPE_SUITE_Group of people  NAME_TYPE_SUITE_Other_A  \
# 154638                              0.0                      0.0
# 167190                              0.0                      0.0
# 121322                              0.0                      0.0
# 67133                               0.0                      0.0
# 150061                              0.0                      0.0
#
#         NAME_TYPE_SUITE_Other_B  NAME_TYPE_SUITE_Spouse, partner  \
# 154638                      0.0                              0.0
# 167190                      0.0                              0.0
# 121322                      0.0                              0.0
# 67133                       0.0                              0.0
# 150061                      0.0                              0.0
#
#         NAME_TYPE_SUITE_Unaccompanied  ...  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 154638                            1.0  ...                    -0.08223
# 167190                            1.0  ...                     0.00000
# 121322                            1.0  ...                    -0.08223
# 67133                             1.0  ...                    -0.08223
# 150061                            1.0  ...                    -0.08223
#
#         AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 154638              -6.705841e-02               -1.796140e-01
# 167190               2.625232e-17               -3.637850e-17
# 121322              -6.705841e-02               -1.796140e-01
# 67133               -6.705841e-02               -1.796140e-01
# 150061              -6.705841e-02               -1.796140e-01
#
#         AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 154638               8.627385e-01              -4.659471e-01
# 167190              -6.536491e-17              -9.722695e-17
# 121322              -3.147711e-01              -4.659471e-01
# 67133               -3.147711e-01              -4.659471e-01
# 150061              -3.147711e-01              -4.659471e-01
#
#         AMT_REQ_CREDIT_BUREAU_YEAR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  \
# 154638                6.327129e-01                 0.0           0.0
# 167190                1.276523e-16                 0.0           0.0
# 121322                5.781787e-02                 0.0           0.0
# 67133                -1.091972e+00                 0.0           0.0
# 150061                6.327129e-01                 0.0           1.0
#
#         FLAG_OWN_REALTY  EMERGENCYSTATE_MODE
# 154638              1.0                  0.0
# 167190              1.0                  0.0
# 121322              1.0                  0.0
# 67133               0.0                  0.0
# 150061              1.0                  0.0
#
# [5 rows x 241 columns]

# %%
X_train_pr.shape, X_train.shape
# Out:
# ((150679, 241), (150679, 121))

# %%
cat_clf = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf = linear_model.LogisticRegression(C=100, max_iter=1000)


fr = print_results(
    fit_results=score_model(cat_clf, X_train_pr, X_test_pr, y_train, y_test, print_res=False),
    model_name='Catboost',
)
cat_score_base = fr['pr-auc']


fr = print_results(
    fit_results=score_model(logreg_clf, X_train_pr, X_test_pr, y_train, y_test, print_res=False),
    model_name='Logreg',
)
logreg_score_base = fr['pr-auc']
# Out:
# Catboost    :		pr-auc: 0.2392	fit_time: 13.7 s
# Logreg      :		pr-auc: 0.2179	fit_time: 25.9 s

# %% [markdown]
# **Задание 9 (1 балл)**
#
#
# Допустим, мы хотим оставить только 50 лучших признаков. Попробуем сделать это несколькими способами. Начнем со способов, заложенных в особенности моделей

# %%
feat_cnt = 50

# %% [markdown]
# **Отбор по feature importance (catboost) (0.5 баллов)**

# %% [markdown]
# Для бустингов над деревями определим важность признака следующим образом: признак тем важнее, чем сильнее влияет его изменение на изменение предсказания
#
# Формально важность признака $f_i(x)$ определяется следующим соотношением:
# $$
# \text{Importance}_i = \sum_{\text{tree} \in \text {trees}} \; \sum_{\text{leaf}_1, \text{leaf}_2 \in LP_i(\text{tree})} c_1 (v_1 - \text{avr})^2 + c_2 (v_2 - \text{avr})^2
# $$
#
# $LP_i(\text{tree})$ --- пары листьев, пути до которых проходят через "разделение" по признаку $f_i(x)$. Причем $\text{leaf}_1$ --- лист, в который мы попадаем по условию $f_i(x) < \text{th}$
#
# Где для каждого листа величины $c_1, c_2, v_1, v_2, \text{avr}$ определяются следующим образом:
# * c_1, c_2 --- вес каждого листа(кол-во принадлежащих листу объектов, если вес не задан явно)
# * v_1, v_2 --- значение в каждом листе
# * $\text{avr} = \frac{c_1 v_1 + c_2 v_2}{c_1 + c_2}$
#
# Таким образом, признак тем важнее, чем сильнее отличаются предсказания в листьях после ветвления по данному признаку

# %% [markdown]
# Получите важности признаков для обученной модели catboost. Разрешается использовать метод $\texttt{.get\_feature\_importance}$. Постройте распределение важности признаков, отберите 50 наиболее важных признаков, обучите Catboost и LogReg на отобранных признаках. (?)Изменилось ли качество и время работы? Какие ещё выводы можно сделать?

# %%
feature_importances = cat_clf.get_feature_importance()
features = X_train_pr.columns

feature_importance_df = pd.DataFrame({"Feature": features, "Importance": feature_importances}).sort_values(by="Importance", ascending=False).head(50)

plt.figure(figsize=(10, 10))
plt.barh(feature_importance_df["Feature"], feature_importance_df["Importance"])
plt.gca().invert_yaxis()
plt.title("Feature Importance (from CatBoost)")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
important_features = feature_importance_df["Feature"].tolist()

X_train_imp_cat = X_train_pr[important_features]
X_test_imp_cat  = X_test_pr[important_features]
print(f"{X_train_imp_cat.shape=}\t\t{X_test_imp_cat.shape=}\n\n")

cat_clf_fs_cat = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf_fs_cat = linear_model.LogisticRegression(C=100, max_iter=1000)

print_results(
    fit_results=score_model(cat_clf_fs_cat, X_train_imp_cat, X_test_imp_cat, y_train, y_test, print_res=False),
    model_name='Catboost',
    base_score=cat_score_base,
)

print_results(
    fit_results=score_model(logreg_clf_fs_cat, X_train_imp_cat, X_test_imp_cat, y_train, y_test, print_res=False),
    model_name='Logreg',
    base_score=logreg_score_base,
)
# Out:
# X_train_imp_cat.shape=(150679, 50)		X_test_imp_cat.shape=(64578, 50)
#
#
# Catboost    :		pr-auc: 0.2393	deviation: 0.0000	fit_time: 8.84 s
# Logreg      :		pr-auc: 0.2165	deviation: -0.0013	fit_time: 0.715 s
# {'pr-auc': 0.21654853000378455, 'fit-time': 0.7146091461181641}

# %% [markdown]
# **Отбор по модулям весов (LogReg) (0.5 баллов)**

# %% [markdown]
# Логистическая регрессия имеет следующий вид:
# $$
# \mathbb{P}(\hat y = 1) = \sigma \left( \sum_{i=1}^{d} w_i f_i(x) \right)
# $$
#
# В силу монотонности $\sigma$ и линейности функции признаки $f_i(x)$ с большими значениями $w_i$ будут вносить основной вклад в предсказание. Поэтому мы будем считать, что для линейной модели признак тем важнее, чем больше его вес.
#
# (?)Всегда ли это будет выполнено? Если нет, то почему?

# %% [markdown]
# (?)Постройте распределение модулей весов. Отберите $50$ наиболее важных признаков по обученной ранее модели, обучите Catboost и LogReg на отобранных признаках. Изменилось ли качество и время работы? Какие ещё выводы можно сделать?

# %%
weights = abs(logreg_clf.coef_[0])
features = X_train_pr.columns

weights_df = pd.DataFrame({"Feature": features, "Weight": weights}).sort_values(by="Weight", ascending=False).head(50)

plt.figure(figsize=(10, 10))
plt.barh(weights_df["Feature"], weights_df["Weight"])
plt.gca().invert_yaxis()
plt.title("Feature Weights (Logistic Regression)")
plt.xlabel("Weight")
plt.ylabel("Feature")
plt.show()

# %%
important_features = weights_df["Feature"].tolist()

X_train_imp_logreg = X_train_pr[important_features]
X_test_imp_logreg  = X_test_pr[important_features]
print(f"{X_train_imp_logreg.shape=}\n{X_test_imp_logreg.shape=}")

cat_clf_fs_logreg = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf_fs_logreg = linear_model.LogisticRegression(C=100, max_iter=1000)


print_results(
    fit_results=score_model(cat_clf_fs_logreg, X_train_imp_logreg, X_test_imp_logreg, y_train, y_test, print_res=False),
    model_name='Catboost',
    base_score=cat_score_base,
)

print_results(
    fit_results=score_model(logreg_clf_fs_logreg, X_train_imp_logreg, X_test_imp_logreg, y_train, y_test, print_res=False),
    model_name='Logreg',
    base_score=logreg_score_base,
)
# Out:
# X_train_imp_logreg.shape=(150679, 50)
# X_test_imp_logreg.shape=(64578, 50)
# Catboost    :		pr-auc: 0.2140	deviation: -0.0253	fit_time: 8.33 s
# Logreg      :		pr-auc: 0.2045	deviation: -0.0134	fit_time: 7.48 s
# {'pr-auc': 0.20448656257540232, 'fit-time': 7.483709096908569}

# %% [markdown]
# (?)**Вопрос**: Мы рассмотрели встроенные методы для линейных моделей и бустингов над деревьями. Отличается ли изменение качества catboost при отборе через "его собственный" feature importance от качества catboost при отборе через модули весов линейной модели? Есть ли отличия изменения качества для LogReg?

# %% [markdown]
# **Ответ**: ВАШ ОТВЕТ

# %% [markdown]
# **Задание 10: Методы фильтрации (0.75 баллов)**

# %% [markdown]
# Давайте отбирать признаки умнее, а именно через подсчёт некоторой функции для каждого признака. На основании значений этой функции будем оставлять наиболее важные признаки. Методы этого семейства называют фильтрующими или  filter methods.
#
# В качестве такой функции будем считать t-статистику:
#
# $$t(x) = \frac{|\mu_+ - \mu_-|}{\sqrt{\frac{n_+ \sigma^2_+ + n_- \sigma^2_-}{n_+ + n_-}}},$$
#
# где $\mu$, $\sigma$, $n$ соответственно среднее, среднеквадратичное отклонение и количество объектов каждого из классов.
#
# Оставьте 50 признаков с наибольшим значением и замерьте качество. Не забудьте замерить скорость отбора признаков в этом случаев.

# %%
def t_stat_values_calculation(data: pd.DataFrame, target) -> np.ndarray:
    class_0 = data[target == 0]
    class_1 = data[target == 1]
    mu_0 = class_0.mean()
    mu_1 = class_1.mean()
    sigma_0 = class_0.std()
    sigma_1 = class_1.std()
    n_0 = class_0.shape[0]
    n_1 = class_1.shape[0]
    return np.abs(mu_0 - mu_1) / np.sqrt(((sigma_0**2 * n_0) + (sigma_1**2 * n_1)) / (n_0 + n_1))

# %%
start_time = time.time()
t_stat_values = t_stat_values_calculation(X_train_pr, y_train).sort_values(ascending=False)
filter_time = time.time() - start_time
print(f"Feature selection time: {filter_time:.4f} seconds")
# Out:
# Feature selection time: 0.2739 seconds

# %%
plt.figure(figsize=(10, 10))
plt.barh(t_stat_values.head(50).index, t_stat_values.head(50))
plt.gca().invert_yaxis()
plt.title(f"T-Statistic Values for Top 50 Features")
plt.xlabel("T-Statistic Value")
plt.ylabel("Features")
plt.tight_layout()
plt.show()

# %%
important_features = t_stat_values.head(50).index.tolist()

X_train_imp_ts = X_train_pr[important_features]
X_test_imp_ts  = X_test_pr[important_features]

print(f"{X_train_imp_ts.shape=}\n{X_test_imp_ts.shape=}")


cat_clf_fs_ts = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf_fs_ts = linear_model.LogisticRegression(C=100, max_iter=1000)

print_results(
    fit_results=score_model(cat_clf_fs_ts, X_train_imp_ts, X_test_imp_ts, y_train, y_test, print_res=False),
    model_name='Catboost',
    base_score=cat_score_base,
)

print_results(
    fit_results=score_model(logreg_clf_fs_ts, X_train_imp_ts, X_test_imp_ts, y_train, y_test, print_res=False),
    model_name='Logreg',
    base_score=logreg_score_base,
)
# Out:
# X_train_imp_ts.shape=(150679, 50)
# X_test_imp_ts.shape=(64578, 50)
# Catboost    :		pr-auc: 0.2358	deviation: -0.0035	fit_time: 8.74 s
# Logreg      :		pr-auc: 0.2155	deviation: -0.0024	fit_time: 3.13 s
# {'pr-auc': 0.21549510664812976, 'fit-time': 3.12990403175354}

# %% [markdown]
# ## Методы-обёртки (Бонус)

# %% [markdown]
# __Задание 11 (бонус).__
#
# __(1 балл)__
#
# Заключительный из рассматриваемых нами методов работает следующим образом: мы исключаем по очереди один из признаков и смотрим, как это влияет на качество. Удаляем признаки таким жадным способом, пока не достигнем некоторого критерия (количество признаков или ухудшением качества).
#
# Заметим, что нельзя оценивать качество по тестовой выборке, иначе мы можем переобучиться, как, например, при настройке гиперпараметров. Разделите выборку на 2 части, на одной из них обучайте модель без одного из признаков,  на второй части оценивайте качество. Исходную тестовую выборку стоит использовать только на финальной оценке качества.
#
# Сделайте одну итерацию и прикиньте, сколько времени займёт такой отбор признаков. Кажется, что чересчур. Давайте возьмём маленький сэмпл данных (например, в 10 тысяч объектов), что сильно уменьшит время итерации. Теперь это долго, но уже приемлимо.
#
# Если это всё ещё долго для вашего комьютера, можете попробовать брать не по одному признаку, а сразу по пять (и удалять сразу тоже по 5). Для этого перед каждой итерацией удаления делите заново все признаки на группы по 5 штук.
#
# Снова оставьте только 50 признаков и оцените качество на тестовой выборке. Сколько времени занял такой отбор признаков?

# %%
import tqdm
import random

class FeatureEliminator:
    def __init__(self, model, data: pd.DataFrame, target):
        self.model = model
        self.data = data
        self.target = target
        self.remaining_features = list(data.columns)

    def feature_elimination(self, min_features: int = 50, log_freq: int = 5) -> np.ndarray:
        """
        Реализация жадного отбора признаков.

        :param min_features: минимальное число отобранных признаков
        :param log_freq: частота логирования
        :return: массив индексов отобранных признаков
        """
        X_train, X_test, y_train, y_test = train_test_split(
            self.data, self.target, test_size=0.2, random_state=73
        )

        while len(self.remaining_features) > min_features:
            scores = []
            features_to_check = list(self.remaining_features)

            for feature in tqdm.tqdm(features_to_check, desc="Evaluating features"):
                temp_features = [f for f in self.remaining_features if f != feature]
                self.model.fit(X_train[temp_features], y_train)
                scores.append((feature, accuracy_score(y_test, self.model.predict(X_test[temp_features]))))
            scores = sorted(scores, key=lambda x: x[1], reverse=True)
            worst_feature, worst_score = scores[-1]
            self.remaining_features.remove(worst_feature)
            if len(self.remaining_features) % log_freq == 0:
                print(f"Remaining features: {len(self.remaining_features)}")
                print(f"Last removed feature: {worst_feature}")

        return self.remaining_features

# %%
cat_clf_fs_fe = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf_fs_fe = linear_model.LogisticRegression(C=100, max_iter=1000)

# %%
cat_fe = FeatureEliminator(cat_clf_fs_fe, X_train_pr, y_train)
logreg_fe = FeatureEliminator(logreg_clf_fs_fe, X_train_pr, y_train)

# %%
start_time = time.time()
cat_fe.feature_elimination(min_features=240)
print(f'FeatureEliminator for CatBoost takes: {time.time()-start_time} seconds for 1 iteration')
# Out:
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 241/241 [45:42<00:00, 11.38s/it]
# Remaining features: 240
# Last removed feature: NAME_HOUSING_TYPE_Office apartment
# FeatureEliminator for CatBoost takes: 2742.4528353214264 seconds for 1 iteration

# %%
start_time = time.time()
logreg_fe.feature_elimination(min_features=240)
print(f'FeatureEliminator for Logreg takes: {time.time()-start_time} seconds for 1 iteration')
# Out:
# Evaluating features: 100%|█████████████████████████████████████████████████████████| 241/241 [1:21:28<00:00, 20.28s/it]
# Remaining features: 240
# Last removed feature: AMT_CREDIT
# FeatureEliminator for Logreg takes: 4888.937685966492 seconds for 1 iteration

# %%
cat_clf_fs_fe = CatBoostClassifier(depth=5, learning_rate=0.05, n_estimators=700, silent=True, random_state=73)
logreg_clf_fs_fe = linear_model.LogisticRegression(C=100, max_iter=1000)

# %%
X_train_sample = X_train_pr.sample(n=10000, random_state=73)
y_train_sample = y_train.loc[X_train_sample.index]
cat_fe = FeatureEliminator(cat_clf_fs_fe, X_train_sample, y_train_sample)
logreg_fe = FeatureEliminator(logreg_clf_fs_fe, X_train_sample, y_train_sample)

# %%
cat_features_fe = cat_fe.feature_elimination(min_features=50)
# Out:
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 238/238 [13:13<00:00,  3.33s/it]
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 237/237 [13:15<00:00,  3.36s/it]
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 236/236 [13:10<00:00,  3.35s/it]
# Remaining features: 235
# Last removed feature: REGION_RATING_CLIENT_W_CITY
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 235/235 [12:56<00:00,  3.30s/it]
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 234/234 [12:58<00:00,  3.33s/it]
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 233/233 [13:12<00:00,  3.40s/it]
# Evaluating features: 100%|███████████████████████████████████████████████████████████| 232/232 [13:34<00:00,  3.51s/it]
# Evaluating features:  70%|█████████████████████████████████████████                  | 161/231 [09:45<04:11,  3.59s/it]

# %%
logreg_fetures = logreg_fe.feature_elimination(min_features=50)

# %% [markdown]
# **Задание 13 (0.75 баллов): Сравнение методов**

# %% [markdown]
# Какие признаки оказались наиболее важными сразу для всех методов отбора? Какая мощность попарных пересечений множеств отобранных признаков?

# %%
### your code here ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# **(?)Вопрос**: Влияет ли выбор стратегии оценивания важности признаков на их ранжирование? Для ответа на полученный вопрос постройте попарные распределения важностей признаков (scatter plots для всех трех пар). Посчитайте коэффициенты ранговой корреляции Спирмана

# %%
import scipy.stats

# %%
_, ax = plt.subplots(ncols=3, figsize=(21, 6))

### your code here ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ

# %% [markdown]
# ## Shapley values (бонус)

# %% [markdown]
# **Задание 12:** Значения Шепли пришли к нам из теории игр, где они использовались для справедливого распределения выигрыша между игроками в кооперативной игре. В контексте машинного обучения мы рассматриваем признаки как "игроков", которые "сотрудничают" для создания предсказания модели.
#
# Значения Шепли вычисляются для каждого объекта $(x_j, y_j)$ независимо. Пусть $v^j(S)$ --- предсказание модели, учитывающей только признаки $f_i(x_j) \in S$. Тогда значение Шепли для $i$-го признака вычисляется по формуле:
# $$
# \varphi_i^j = \sum_{S \subset N \setminus \{i\}} \frac{C_{n}^{|S|}}{n} (v^j(S \cup {i}) - v^j(S))
# $$
#
# Оказывается, что значения Шепли (они и только они) обладают следующими свойствами:
# 1. Сумма значений Шепли всех признаков равна разнице между предсказанием модели и средним предсказанием по датасету: $\sum_{i = 1}^N \varphi_i^j~=~\hat y_j~-~\frac{\sum_{s=1}^l \hat y_s}{l}$
# 2. Если два признака вносят одинаковый вклад при объединением с любой комбинацией других признаков, их значения Шепли будут равны
# 3. Если признак не влияет на предсказание, то ему будет соответствовать нулевое значение Шепли
# 4. Линейность: значения Шеппли для суммы игр равны сумме значений для игр
#
# Для нас оказываются важными свойства 1, 2, 3. Например, если два признака линейно зависимы то все предыдущие методы оценивания важности могли дать различные значения важности для данных признаков, значения Шепли для данных признаков окажутся равными (для линейных моделей и ансамблей над деревьями).
#
# Основным недостатком Shapley values является сложность вычислений: в общем случае требуется осуществить полный перебор. Однако, для некоторых классов моделей (линейные, бустинги над деревьями и некоторые другие) даныне значения считаются за полиномиальное время.
#
# Для вычисления и визуализации Shapley values используется пакет [shap](https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html)

# %%
# для выполнения задания необходимо установить пакет shap
import shap

# shap.initjs()

# %% [markdown]
# Посчитайте Shapley values для catboost'ов, обученных на:
# 1. Всех признаках
# 2. Признаках, отобранных по feature selection (catboost)
# 3. Признаках, отобранных по модулям весов линейной модели
# 4. Признаках, отобранных по t-статистике

# %%
explainer = shap.TreeExplainer(cat_clf)
shap_values = explainer(X_train_pr)

explainer_cat = shap.TreeExplainer(cat_clf_fs_cat) # Explainer for catboost trained on selected by catboost features
shap_values_cat = explainer_cat(X_train_imp_cat)

explainer_logreg = shap.TreeExplainer(cat_clf_fs_logreg) # Explainer for catboost trained on selected by logreg features
shap_values_logreg = explainer_logreg(X_train_imp_logreg)

explainer_ts = shap.TreeExplainer(cat_clf_fs_ts) # Explainer for catboost trained on selected by t-stat features
shap_values_ts = explainer_ts(X_train_imp_ts)

# %% [markdown]
# ### (0.5 баллов)Демонстрация всех shap values
#
# В данном задании предлагается проанализировать визуализацию распределений значений Шепли по всем объектам из датасета.
#
# Summary plot из позволяет комплексно оценить влияние признаков на предсказания модели. При анализе графика необходимо обращать внимание на четыре ключевых аспекта:
# * Чем сильнее точки признака растянуты вдоль оси, тем более значимое влияние оказывает этот признак на предсказания модели. Концентрация точек около нуля говорит о слабом влиянии признака.
# * Градиент от синего к красному показывает значения признака от низких к высоким. Если красные точки сгруппированы с одной стороны, а синие с другой – существует монотонная зависимость. Перемешанные цвета указывают на сложную нелинейную связь.
# * Области высокой плотности показывают типичное влияние признака, а отдельно стоящие точки могут указывать на выбросы или особые случаи
# * Признаки отсортированы по силе влияния сверху вниз.
#
# **Вопрос**: Какие признаки оказываются "наиболее влиятельными" при использовании различных стратегий отбора признаков? Отличаются ли построенные графики? Если да, то какие выводы можно сделать?

# %%
# Before feature selection

ax = plt.gca()
ax.set_title('Before feature selection', fontdict={'fontsize': 16})

shap.summary_plot(shap_values, plot_size=(21, 6))

# %%
# Feature selection by catboost

ax = plt.gca()
ax.set_title('Selected by Catboost', fontdict={'fontsize': 16})

shap.summary_plot(shap_values_cat, plot_size=(21, 6))

# %%
# Feature selection by logreg

ax = plt.gca()
ax.set_title('Selected by LogReg', fontdict={'fontsize': 16})

shap.summary_plot(shap_values_logreg, plot_size=(21, 6))

# %%
# Feature selection by t-statistic

ax = plt.gca()
ax.set_title('Selected by t-statistic', fontdict={'fontsize': 16})

shap.summary_plot(shap_values_ts, plot_size=(21, 6))

# %% [markdown]
# Ответ: ВАШ ОТВЕТ ТУТ

# %% [markdown]
# ### (1 балл) Объяснение предсказания для объекта
#
# Waterfall график из библиотеки SHAP позволяет детально проанализировать, как каждый признак повлиял на конкретное предсказание модели. Этот тип визуализации показывает путь от базового значения модели к итоговому предсказанию.
#
# Самым важным в анализе является последовательное влияние признаков. Красные полосы показывают увеличение предсказанного значения, синие – уменьшение. При анализе необходимо обращать внимание на соотношение положительных и отрицательных вкладов. Часто признаки могут компенсировать влияние друг друга, и важно оценить результирующий эффект. Такая визуализация особенно полезна для объяснения конкретных решений модели заинтересованным лицам, так как наглядно показывает, какие факторы и насколько сильно повлияли на итоговый результат.
#
# **(?) Вопрос**: Отличаются ли построенные графики? Если да, то какие выводы можно сделать? Посмотрите на объяснения для нескольких объектов. В итоговой версии ноутбука можно оставить визуализацию только для одного объекта.

# %%
obj_idx = 1

# %%
ax = plt.gca()
ax.set_title('Before feature selection', fontdict={'fontsize': 16})

shap.plots.waterfall(...)

# %%
ax = plt.gca()
ax.set_title('Selected by Catboost', fontdict={'fontsize': 16})

shap.plots.waterfall(...)

# %%
ax = plt.gca()
ax.set_title('Selected by LogReg', fontdict={'fontsize': 16})

shap.plots.waterfall(...)

# %%
ax = plt.gca()
ax.set_title('Selected by t-statistic', fontdict={'fontsize': 16})

shap.plots.waterfall(...)

# %% [markdown]
# Ответ: ВАШ ОТВЕТ ТУТ

# %% [markdown]
# **Бонус (0.2 балла)**
#
# Ваш любимый новогодний фильм/сериал/мультик/книга/музыка/развление/ч-т-о-у-г-о-д-н-о
#
# Всем мандаринок!&#127818;

# %% [markdown]
# #### Ваш ответ здесь╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ
# ![мем.jpg](https://i.pinimg.com/736x/7e/33/dc/7e33dce22b4b9f3af3452669dd8efc56.jpg)

# %% [markdown]
# ![image.png](https://i.pinimg.com/736x/2c/9e/f3/2c9ef3519cd5b5fd21726f05e7d78ea2.jpg)
